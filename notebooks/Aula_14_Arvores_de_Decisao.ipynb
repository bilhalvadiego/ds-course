# %% [markdown]
# <a id='section-zero'></a>

# %% [markdown]
# # Árvores de Decisão (*Decision Trees*)
#
# **Objetivos**: Aprender o que é Árvores de Decisão usando a biblioteca `Scikit-Learn`.

# %% [markdown]
# ## O que é uma Árvore de Decisão?
#
# Uma árvore de decisão é uma estrutura do tipo fluxograma na qual cada nó interno representa um "teste" em um atributo (por exemplo, se um lançamento de moeda aparece cara ou coroa), cada ramo representa o resultado do teste e cada nó folha representa um rótulo de classe (decisão tomada após o cálculo de todos os atributos). Os caminhos da raiz para a folha representam regras de classificação.

# %% [markdown]
# ## Elementos de uma Árvore de Decisão
#
# * **Árvore** (*Tree*): Mapeamento de uma decisão composta por nós e folhas
# * **Nó de Decisão** (*Node*): Quando um nó se divide em outros sub-nós, ele é chamado de nó de decisão
# * **Raiz** (*Root*): Primeiro nó de decisão
# * **Folha** (*Leaf*): Os nós não divididos são chamados de nó folha
#
# <img src="images/arvore-decisao.jpg" alt="arvore-decisao" width="30%"/>

# %% [markdown]
# ## Impureza de Nós - Classificação
#
# * Um nó é puro quando todas as observações que ele aplica decisões são da mesma classe.
# * Quanto menor mais puro o nó
# * Mensurado por
# 	* Índice de Gini: Menor custo computacional
# 	* Entropia: Maior custo computacional
# 	* Na maioria das vezes não faz diferença Gini ou Entropia.
# 		* Mas quando há diferença, Entropia tende a gerar árvores mais equilibradas
#
# ## Impureza de Nós - Regressão
#
# * Um nó é puro quando todas as observações que ele aplica decisões possuem erro zero.
# * Quanto menor mais puro o nó
# * Mensurado por
# 	* MSE: Maior punição para erros "grosseiros"
# 	* MAE: Punição igual para todos os erros

# %% [markdown]
# ## Classificação e Regressão
#
# * Classificação: [`sklearn.tree.DecisionTreeClassifier()`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
# * Regressão: [`sklearn.tree.DecisionTreeRegressor()`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %% [markdown]
# ## Hiperparâmetros
#
# * **Profundidade Máxima das Árvores**: Número máximo de nós que devem existir em uma dada árvore
# * **Quantidade Mínima de Observações para uma Decisão**: Mínimo de observações que um nó deve ter para ser separado

# %% [markdown]
# ## Exemplo com o Dataset Titanic
#
# Contém 891 passageiros reais do Titanic que afundou em 15/04/1912 matando 1502 de 2224 passageiros e tripulação que estavam a bordo.
#
# * `survived`: *dummy* `0` ou `1`
# * `pclass`: Classe do Passageiro
#     - `1`: Primeira Classe
#     - `2`: Segunda Classe
#     - `3`: Terceira Classe
# * `sex`: Sexo `male` ou `female`
# * `age`: Idade
# * `sibsp`: Número de Irmãos (*Siblings*) e Esposas (*spouse*) a bordo
# * `parch`: Número de pais/filhos a bordo
# * `fare`: Valor pago pela passagem em libras
# * `embarked`: Porto que embarcou
#     - `C`: Cherbourg
#     - `Q`: Queenstown
#     - `S`: Southampton)
# * `class`: Mesmo que `pclass` só que em texto
# * `adult_male`: *dummy* para `age > 16` e `sex == 'male'`
# * `deck`: Qual deck a cabine do passageiro se situava
# * `alive`: Mesmo que survived só que com `yes` ou `no`
# * `alone`: *dummy* para se viajava sozinho

# %% [markdown]
# <img src="images/titanic.png" alt="titanic" style="width: 500px;"/>

# %%
# import seaborn as sns
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
titanic = sns.load_dataset('titanic')

feature_names = ['pclass', 'female', 'age', 'fare']
titanic['female'] = titanic['sex'].map({'male': 0, 'female': 1})
titanic.dropna(subset=feature_names, inplace=True)  #891 para 714

X = titanic[feature_names]
y = titanic['survived']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    stratify=y,
                                                    random_state=1)

# %%
print('Tamanho de X_train: ', X_train.shape)
print('Tamanho de X_test: ', X_test.shape)
print('Tamanho de y_train: ', y_train.shape)
print('Tamanho de y_test: ', y_test.shape)
# Out:
# Tamanho de X_train:  (535, 4)
# Tamanho de X_test:  (179, 4)
# Tamanho de y_train:  (535,)
# Tamanho de y_test:  (179,)

# %% [markdown]
# ### Árvore de Decisão - Classificação
# Usar a classe do Scikit-Learn [`sklearn.tree.DecisionTreeClassifier()`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#
# #### Argumentos:
# * `criterion` - `str` - Critério de Impureza (Gini ou Entropia)
#     * `'gini'` - padrão
#     * `'entropy'`
# * `max_depth` - `int` - Profundidade Máxima da Árvore
# * `min_samples_split` - `int` ou `float` - padrão `2` - Quantidade Mínima de Observações para uma Decisão
# * `min_samples_leaf` - `int` ou `float` - Quantidade Mínima de Observações para que um Nó vire Folha (não tenha mais outros nós abaixo)
# * `random_state` - `int` - seed do gerador de número randômicos (replicabilidade)
#
# #### Retorna:
# * Objeto `estimator` do Scikit-Learn

# %% [markdown]
# ### Árvore de Regressão
# Usar a classe do Scikit-Learn [`sklearn.tree.DecisionTreeRegressor()`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)
#
# #### Argumentos:
# * `criterion` - `str` - Critério de Impureza (MSE ou MAE)
#     * `'mse'` - padrão
#     * `'mae'`
# * `max_depth` - `int` - Profundidade Máxima da Árvore
# * `min_samples_split` - `int` ou `float` - padrão `2` - Quantidade Mínima de Observações para uma Decisão
# * `min_samples_leaf` - `int` ou `float` - Quantidade Mínima de Observações para que um Nó vire Folha (não tenha mais outros nós abaixo)
# * `random_state` - `int` - seed do gerador de número randômicos (replicabilidade)
#
# #### Retorna:
# * Objeto `estimator` do Scikit-Learn

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=4,
                             min_samples_leaf=30,
#                              min_samples_split=20,
                             random_state=5252)
clf.fit(X_train, y_train) #treino com fatos
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=30, random_state=5252)

# %% [markdown]
# ### Acurácia do Modelo
# Usar a função do Scikit-Learn [`sklearn.metrics.accuracy_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#
# Retorna um score de acurácia `float` entre $0$ e $1$
#
# #### Argumentos
# * `y_true`: Classes Verdadeiras
#     * 2 classes: vetor (1-D)
#     * Mais que 2 classes: matriz (2-D)
# * `y_pred`: Classes Previstas pelo Modelo
#     * 2 classes: vetor (1-D)
#     * Mais que 2 classes: matriz (2-D)
#
# > Obs: Regressão Logística acurácias: 0.69 Treino e 0.7 Teste
#
# > Obs: *Support Vector Machines* acurácias: 0.79 Treino e 0.75 Teste

# %%
from sklearn.metrics import accuracy_score

y_train_true = y_train
y_train_pred = clf.predict(X_train)
y_test_true = y_test
y_test_pred = clf.predict(X_test)


print(f"Acurácia de Treino: {round(accuracy_score(y_train_true, y_train_pred), 4)}")
print('\n ---------------------------\n')
print(f"Acurácia de Teste: {round(accuracy_score(y_test_true, y_test_pred), 4)}")
# Out:
# Acurácia de Treino: 0.815
#
#  ---------------------------
#
# Acurácia de Teste: 0.7654

# %% [markdown]
# ### Plotando a Árvore
#
# Usar a função do Scikit-Learn [`sklearn.tree.plot_tree()`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html). Usar junto com o `matplotlib.pyplot`.
#
# Lembrando nossos features
#
# * `X[0]` = `'pclass'`
# * `X[1]` = `'female'`
# * `X[2]` = `'age'`
# * `X[3]` = `'fare'`

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

from sklearn.tree import plot_tree

plt.figure(figsize=(20,8))
plot_tree(
    clf
    , filled=True
    , class_names={0:'Morrer', 1:'Viver'}
    , feature_names={0:'pclass', 1:'female', 2:'age', 3:'fare'}
)
plt.show()

# %% [markdown]
# ## Atividade - Árvores de Decisão com o dataset [Iris](https://scikit-learn.org/stable/datasets/index.html#iris-dataset)
#
# Edgar Anderson coletou os dados para quantificar a variação morfológica das flores de íris de três espécies relacionadas.
#
# O conjunto de dados consiste em 50 amostras de cada uma das três espécies de Iris (Setosa, Virginica e Versicolor). Quatro características foram medidas em cada amostra (cm):
#
# * $N = 150$
# * Atributos: 4
#     * `sepal length (cm)` - Cumprimento da Sépala
#     * `sepal width (cm)` - Largura da Sépala
#     * `petal length (cm)` - Cumprimento da Pétala
#     * `petal width (cm)` - Largua da Sépala
# * Variável dependente: Tipo de espécie de Iris
#     * `0` - Setosa
#     * `1` - Virginica
#     * `2` - Versicolor
#
# * Achar a acurácia do modelo para os dados de teste
#
# >Obs: usar `test_size = 0.25` e `random_state = 123`

# %% [markdown]
# <img src="images/iris-species.png" alt="iris-sepals-petals" style="width: 600px;"/>

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris['data']
y = iris['target']

# %%
print('Nomes dos Atributos: ', iris['feature_names'], '\n')
print('Tamanho de X: ', X.shape, '\n')
print('Tamanho de y: ', y.shape, '\n')
# Out:
# Nomes dos Atributos:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# Tamanho de X:  (150, 4)
#
# Tamanho de y:  (150,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
print('Tamanho de X_train: ', X_train.shape, '\n')
print('Tamanho de X_test: ', X_test.shape, '\n')
print('Tamanho de y_train: ', y_train.shape, '\n')
print('Tamanho de y_test: ', y_test.shape, '\n')
# Out:
# Tamanho de X_train:  (112, 4)
#
# Tamanho de X_test:  (38, 4)
#
# Tamanho de y_train:  (112,)
#
# Tamanho de y_test:  (38,)

# %% [markdown]
# ## Extra - Titanic

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

max_range_depth = [2]
# max_range_depth = [2, 3, 4, 5, 6, 7, 8, 9, 10]

for depth in max_range_depth:
    for msplit in [10, 15, 20, 25, 30]:
        clf = DecisionTreeClassifier(max_depth=depth,
                                     min_samples_split=msplit,
                                     random_state=123)
        clf.fit(X_train, y_train) #treino com fatos



        y_train_true = y_train
        y_train_pred = clf.predict(X_train)
        y_test_true = y_test
        y_test_pred = clf.predict(X_test)


        print("Acurácia de Treino para depth {0}: {1}".format(depth, round(accuracy_score(y_train_true, y_train_pred), 4)))
#     print('\n ---------------------------\n')
#     print(f"Acurácia de Teste: {round(accuracy_score(y_test_true, y_test_pred), 4)}")
# Out:
# Acurácia de Treino para depth 2: 0.9643
# Acurácia de Treino para depth 2: 0.9643
# Acurácia de Treino para depth 2: 0.9643
# Acurácia de Treino para depth 2: 0.9643
# Acurácia de Treino para depth 2: 0.9643

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

from sklearn.tree import plot_tree

plt.figure(figsize=(20,8))
plot_tree(
    clf
    , filled=True
    , class_names={0:'Morrer', 1:'Viver'}
    , feature_names={0:'pclass', 1:'female', 2:'age', 3:'fare'}
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 11
#       8 from sklearn.tree import plot_tree
#      10 plt.figure(figsize=(20,8))
# ---> 11 plot_tree(
#      12     clf
#      13     , filled=True
#      14     , class_names={0:'Morrer', 1:'Viver'}
#      15     , feature_names={0:'pclass', 1:'female', 2:'age', 3:'fare'}
#      16 )
#      17 plt.show()
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:194, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     179 check_is_fitted(decision_tree)
#     181 exporter = _MPLTreeExporter(
#     182     max_depth=max_depth,
#     183     feature_names=feature_names,
#    (...)
#     192     fontsize=fontsize,
#     193 )
# --> 194 return exporter.export(decision_tree, ax=ax)
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:655, in _MPLTreeExporter.export(self, decision_tree, ax)
#     653 ax.clear()
#     654 ax.set_axis_off()
# --> 655 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     656 draw_tree = buchheim(my_tree)
#     658 # important to make sure we're still
#     659 # inside the axis after drawing the box
#     660 # this makes sense because the width of a box
#     661 # is about the same as the distance between boxes
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:639, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     631 name = self.node_to_str(et, node_id, criterion=criterion)
#     632 if et.children_left[node_id] != _tree.TREE_LEAF and (
#     633     self.max_depth is None or depth <= self.max_depth
#     634 ):
#     635     children = [
#     636         self._make_tree(
#     637             et.children_left[node_id], et, criterion, depth=depth + 1
#     638         ),
# --> 639         self._make_tree(
#     640             et.children_right[node_id], et, criterion, depth=depth + 1
#     641         ),
#     642     ]
#     643 else:
#     644     return Tree(name, node_id)
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:639, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     631 name = self.node_to_str(et, node_id, criterion=criterion)
#     632 if et.children_left[node_id] != _tree.TREE_LEAF and (
#     633     self.max_depth is None or depth <= self.max_depth
#     634 ):
#     635     children = [
#     636         self._make_tree(
#     637             et.children_left[node_id], et, criterion, depth=depth + 1
#     638         ),
# --> 639         self._make_tree(
#     640             et.children_right[node_id], et, criterion, depth=depth + 1
#     641         ),
#     642     ]
#     643 else:
#     644     return Tree(name, node_id)
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:631, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     628 def _make_tree(self, node_id, et, criterion, depth=0):
#     629     # traverses _tree.Tree recursively, builds intermediate
#     630     # "_reingold_tilford.Tree" object
# --> 631     name = self.node_to_str(et, node_id, criterion=criterion)
#     632     if et.children_left[node_id] != _tree.TREE_LEAF and (
#     633         self.max_depth is None or depth <= self.max_depth
#     634     ):
#     635         children = [
#     636             self._make_tree(
#     637                 et.children_left[node_id], et, criterion, depth=depth + 1
#    (...)
#     641             ),
#     642         ]
#
# File ~/Documents/venv/python3/lib/python3.11/site-packages/sklearn/tree/_export.py:366, in _BaseTreeExporter.node_to_str(self, tree, node_id, criterion)
#     364     node_string += "class = "
#     365 if self.class_names is not True:
# --> 366     class_name = self.class_names[np.argmax(value)]
#     367 else:
#     368     class_name = "y%s%s%s" % (
#     369         characters[1],
#     370         np.argmax(value),
#     371         characters[2],
#     372     )
#
# KeyError: 2

# %% [markdown]
# Extra Exercise

# %%
import pandas as pd
SEED = 5252

boston = pd.read_csv('https://raw.githubusercontent.com/bilhalvadiego/ds-course/main/notebooks/data/BostonHousing.csv')

X = boston.loc[:,'crim':'lstat']
y = boston['medv']

feature_names = X.columns

feature_names
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

from sklearn.tree import DecisionTreeRegressor

max_range_depth = [2, 3, 4, 5, 6, 7, 8, 9, 10]

max_test_value = {'criterion':None, 'max_depth':None, 'min_samples_split':None, 'max_value':0}
for crit in ['squared_error', 'absolute_error']:
    for depth in max_range_depth:
        for msplit in [10, 15, 20, 25, 30]:
            dtr = DecisionTreeRegressor(
                criterion=crit
                ,max_depth=depth
                ,min_samples_split=msplit
                ,random_state=123
            )

            dtr.fit(X_train, y_train)
            
            test_score = round(round(dtr.score(X_test, y_test)/dtr.score(X_train, y_train),4),4)
            max_test_value = {'criterion':crit, 'max_depth':depth, 'min_samples_split':msplit, 'max_value':round(dtr.score(X_test, y_test)/dtr.score(X_train, y_train),4)} if test_score > max_test_value['max_value'] else max_test_value
            print('Treino - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_train, y_train),4)))
            print('Teste - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_test, y_test),4)))

max_test_value
# Out:
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 10 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 10 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 15 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 15 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 20 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 20 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 25 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 25 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 30 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 30 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 10 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 10 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 15 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 15 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 20 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 20 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 25 ==> 0.8141
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 25 ==> 0.465
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 30 ==> 0.8047
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 30 ==> 0.5571
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 10 ==> 0.8847
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 10 ==> 0.5551
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 15 ==> 0.8847
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 15 ==> 0.5551
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 20 ==> 0.8823
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 20 ==> 0.5564
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 25 ==> 0.877
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 25 ==> 0.5336
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 30 ==> 0.86
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 30 ==> 0.6238
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 10 ==> 0.9165
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 10 ==> 0.5511
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 15 ==> 0.9148
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 15 ==> 0.5596
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 20 ==> 0.9105
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 20 ==> 0.563
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 25 ==> 0.9052
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 25 ==> 0.5402
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 30 ==> 0.8852
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 30 ==> 0.6336
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 10 ==> 0.9407
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 10 ==> 0.4805
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 15 ==> 0.9319
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 15 ==> 0.5595
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 20 ==> 0.9238
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 20 ==> 0.5641
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 25 ==> 0.9185
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 25 ==> 0.5412
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 30 ==> 0.8986
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 30 ==> 0.6347
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 10 ==> 0.9535
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 10 ==> 0.5228
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 15 ==> 0.9421
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 15 ==> 0.5607
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 20 ==> 0.9328
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 20 ==> 0.5687
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 25 ==> 0.9263
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 25 ==> 0.5455
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 30 ==> 0.9052
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 30 ==> 0.6353
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 10 ==> 0.9603
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 10 ==> 0.4777
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 15 ==> 0.9481
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 15 ==> 0.5544
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 20 ==> 0.9371
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 20 ==> 0.5628
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 25 ==> 0.9306
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 25 ==> 0.5396
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 30 ==> 0.9094
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 30 ==> 0.6294
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 10 ==> 0.9669
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 10 ==> 0.4775
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 15 ==> 0.9543
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 15 ==> 0.5521
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 20 ==> 0.9401
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 20 ==> 0.5649
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 25 ==> 0.933
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 25 ==> 0.5413
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 30 ==> 0.911
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 30 ==> 0.6305
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 10 ==> 0.971
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 10 ==> 0.5105
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 15 ==> 0.9575
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 15 ==> 0.548
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 20 ==> 0.9413
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 20 ==> 0.564
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 25 ==> 0.9336
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 25 ==> 0.5431
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 30 ==> 0.911
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 30 ==> 0.6305
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 10 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 10 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 15 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 15 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 20 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 20 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 25 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 25 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 30 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 30 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 10 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 10 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 15 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 15 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 20 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 20 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 25 ==> 0.8076
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 25 ==> 0.6198
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 30 ==> 0.8076
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 30 ==> 0.6198
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 10 ==> 0.8752
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 10 ==> 0.764
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 15 ==> 0.871
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 15 ==> 0.7839
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 20 ==> 0.871
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 20 ==> 0.7839
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 25 ==> 0.8642
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 25 ==> 0.7596
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 30 ==> 0.8642
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 30 ==> 0.7596
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 10 ==> 0.9109
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 10 ==> 0.8032
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 15 ==> 0.9036
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 15 ==> 0.8233
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 20 ==> 0.8989
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 20 ==> 0.8167
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 25 ==> 0.8922
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 25 ==> 0.7923
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 30 ==> 0.8922
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 30 ==> 0.7923
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 10 ==> 0.9412
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 10 ==> 0.7997
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 15 ==> 0.9187
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 15 ==> 0.8217
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 20 ==> 0.9106
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 20 ==> 0.8182
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 25 ==> 0.9009
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 25 ==> 0.7939
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 30 ==> 0.9
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 30 ==> 0.7939
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 10 ==> 0.9549
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 10 ==> 0.7984
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 15 ==> 0.9287
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 15 ==> 0.8223
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 20 ==> 0.9195
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 20 ==> 0.8193
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 25 ==> 0.9058
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 25 ==> 0.8024
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 30 ==> 0.904
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 30 ==> 0.8013
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 10 ==> 0.962
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 10 ==> 0.8048
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 15 ==> 0.9346
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 15 ==> 0.8267
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 20 ==> 0.9216
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 20 ==> 0.8197
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 25 ==> 0.9078
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 25 ==> 0.8028
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 30 ==> 0.906
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 30 ==> 0.8018
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 10 ==> 0.9684
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 10 ==> 0.764
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 15 ==> 0.9388
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 15 ==> 0.8236
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 20 ==> 0.9231
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 20 ==> 0.8156
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 25 ==> 0.9084
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 25 ==> 0.8012
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 30 ==> 0.9066
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 30 ==> 0.8002
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 10 ==> 0.973
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 10 ==> 0.7798
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 15 ==> 0.9394
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 15 ==> 0.8072
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 20 ==> 0.9237
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 20 ==> 0.8156
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 25 ==> 0.9084
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 25 ==> 0.8012
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.9066
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.8002
# {'criterion': 'absolute_error',
#  'max_depth': 5,
#  'min_samples_split': 15,
#  'max_value': 0.9112}

# %%
dtr = DecisionTreeRegressor(
    criterion=max_test_value['criterion']
    ,max_depth=max_test_value['max_depth']
    ,min_samples_split=max_test_value['min_samples_split']
    ,random_state=123
)

dtr.fit(X_train, y_train)

print('Treino - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_train, y_train),4)))
print('Teste - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_test, y_test),4)))
# Out:
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.9036
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.8233

# %% [markdown]
# Standard

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

from sklearn.tree import DecisionTreeRegressor

max_range_depth = [2, 3, 4, 5, 6, 7, 8, 9, 10]

for crit in ['squared_error', 'absolute_error']:
    for depth in max_range_depth:
        for msplit in [10, 15, 20, 25, 30]:
            dtr = DecisionTreeRegressor(
                criterion=crit
                ,max_depth=depth
                ,min_samples_split=msplit
                ,random_state=123
            )

            dtr.fit(X_train, y_train)
            test_score = round(round(dtr.score(X_test, y_test)/dtr.score(X_train, y_train),4),4)
            max_test_value = {'criterion':crit, 'max_depth':depth, 'min_samples_split':msplit, 'max_value':round(dtr.score(X_test, y_test)/dtr.score(X_train, y_train),4)} if test_score > max_test_value['max_value'] else max_test_value
            print('Treino - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_train, y_train),4)))
            print('Teste - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_test, y_test),4)))

max_test_value
# Out:
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 10 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 10 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 15 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 15 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 20 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 20 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 25 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 25 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 2, min_samples_split: 30 ==> 0.7326
# Teste - criterion: squared_error, max_depth: 2, min_samples_split: 30 ==> 0.5565
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 10 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 10 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 15 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 15 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 20 ==> 0.8194
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 20 ==> 0.4878
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 25 ==> 0.8141
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 25 ==> 0.465
# Treino - criterion: squared_error, max_depth: 3, min_samples_split: 30 ==> 0.8047
# Teste - criterion: squared_error, max_depth: 3, min_samples_split: 30 ==> 0.5571
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 10 ==> 0.8847
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 10 ==> 0.5551
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 15 ==> 0.8847
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 15 ==> 0.5551
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 20 ==> 0.8823
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 20 ==> 0.5564
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 25 ==> 0.877
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 25 ==> 0.5336
# Treino - criterion: squared_error, max_depth: 4, min_samples_split: 30 ==> 0.86
# Teste - criterion: squared_error, max_depth: 4, min_samples_split: 30 ==> 0.6238
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 10 ==> 0.9165
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 10 ==> 0.5511
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 15 ==> 0.9148
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 15 ==> 0.5596
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 20 ==> 0.9105
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 20 ==> 0.563
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 25 ==> 0.9052
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 25 ==> 0.5402
# Treino - criterion: squared_error, max_depth: 5, min_samples_split: 30 ==> 0.8852
# Teste - criterion: squared_error, max_depth: 5, min_samples_split: 30 ==> 0.6336
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 10 ==> 0.9407
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 10 ==> 0.4805
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 15 ==> 0.9319
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 15 ==> 0.5595
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 20 ==> 0.9238
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 20 ==> 0.5641
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 25 ==> 0.9185
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 25 ==> 0.5412
# Treino - criterion: squared_error, max_depth: 6, min_samples_split: 30 ==> 0.8986
# Teste - criterion: squared_error, max_depth: 6, min_samples_split: 30 ==> 0.6347
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 10 ==> 0.9535
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 10 ==> 0.5228
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 15 ==> 0.9421
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 15 ==> 0.5607
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 20 ==> 0.9328
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 20 ==> 0.5687
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 25 ==> 0.9263
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 25 ==> 0.5455
# Treino - criterion: squared_error, max_depth: 7, min_samples_split: 30 ==> 0.9052
# Teste - criterion: squared_error, max_depth: 7, min_samples_split: 30 ==> 0.6353
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 10 ==> 0.9603
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 10 ==> 0.4777
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 15 ==> 0.9481
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 15 ==> 0.5544
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 20 ==> 0.9371
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 20 ==> 0.5628
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 25 ==> 0.9306
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 25 ==> 0.5396
# Treino - criterion: squared_error, max_depth: 8, min_samples_split: 30 ==> 0.9094
# Teste - criterion: squared_error, max_depth: 8, min_samples_split: 30 ==> 0.6294
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 10 ==> 0.9669
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 10 ==> 0.4767
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 15 ==> 0.9543
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 15 ==> 0.5513
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 20 ==> 0.9401
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 20 ==> 0.5642
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 25 ==> 0.933
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 25 ==> 0.5413
# Treino - criterion: squared_error, max_depth: 9, min_samples_split: 30 ==> 0.911
# Teste - criterion: squared_error, max_depth: 9, min_samples_split: 30 ==> 0.6305
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 10 ==> 0.971
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 10 ==> 0.51
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 15 ==> 0.9575
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 15 ==> 0.5475
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 20 ==> 0.9413
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 20 ==> 0.5633
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 25 ==> 0.9336
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 25 ==> 0.5431
# Treino - criterion: squared_error, max_depth: 10, min_samples_split: 30 ==> 0.911
# Teste - criterion: squared_error, max_depth: 10, min_samples_split: 30 ==> 0.6305
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 10 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 10 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 15 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 15 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 20 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 20 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 25 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 25 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 2, min_samples_split: 30 ==> 0.7267
# Teste - criterion: absolute_error, max_depth: 2, min_samples_split: 30 ==> 0.5342
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 10 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 10 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 15 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 15 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 20 ==> 0.8144
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 20 ==> 0.6442
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 25 ==> 0.8076
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 25 ==> 0.6198
# Treino - criterion: absolute_error, max_depth: 3, min_samples_split: 30 ==> 0.8076
# Teste - criterion: absolute_error, max_depth: 3, min_samples_split: 30 ==> 0.6198
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 10 ==> 0.8752
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 10 ==> 0.764
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 15 ==> 0.871
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 15 ==> 0.7839
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 20 ==> 0.871
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 20 ==> 0.7839
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 25 ==> 0.8642
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 25 ==> 0.7596
# Treino - criterion: absolute_error, max_depth: 4, min_samples_split: 30 ==> 0.8642
# Teste - criterion: absolute_error, max_depth: 4, min_samples_split: 30 ==> 0.7596
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 10 ==> 0.9109
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 10 ==> 0.8032
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 15 ==> 0.9036
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 15 ==> 0.8233
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 20 ==> 0.8989
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 20 ==> 0.8167
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 25 ==> 0.8922
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 25 ==> 0.7923
# Treino - criterion: absolute_error, max_depth: 5, min_samples_split: 30 ==> 0.8922
# Teste - criterion: absolute_error, max_depth: 5, min_samples_split: 30 ==> 0.7923
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 10 ==> 0.9412
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 10 ==> 0.7997
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 15 ==> 0.9187
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 15 ==> 0.8217
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 20 ==> 0.9106
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 20 ==> 0.8182
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 25 ==> 0.9009
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 25 ==> 0.7939
# Treino - criterion: absolute_error, max_depth: 6, min_samples_split: 30 ==> 0.9
# Teste - criterion: absolute_error, max_depth: 6, min_samples_split: 30 ==> 0.7939
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 10 ==> 0.9549
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 10 ==> 0.7984
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 15 ==> 0.9287
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 15 ==> 0.8223
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 20 ==> 0.9195
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 20 ==> 0.8193
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 25 ==> 0.9058
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 25 ==> 0.8024
# Treino - criterion: absolute_error, max_depth: 7, min_samples_split: 30 ==> 0.904
# Teste - criterion: absolute_error, max_depth: 7, min_samples_split: 30 ==> 0.8013
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 10 ==> 0.962
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 10 ==> 0.8048
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 15 ==> 0.9346
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 15 ==> 0.8267
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 20 ==> 0.9216
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 20 ==> 0.8197
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 25 ==> 0.9078
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 25 ==> 0.8028
# Treino - criterion: absolute_error, max_depth: 8, min_samples_split: 30 ==> 0.906
# Teste - criterion: absolute_error, max_depth: 8, min_samples_split: 30 ==> 0.8018
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 10 ==> 0.9684
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 10 ==> 0.764
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 15 ==> 0.9388
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 15 ==> 0.8236
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 20 ==> 0.9231
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 20 ==> 0.8156
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 25 ==> 0.9084
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 25 ==> 0.8012
# Treino - criterion: absolute_error, max_depth: 9, min_samples_split: 30 ==> 0.9066
# Teste - criterion: absolute_error, max_depth: 9, min_samples_split: 30 ==> 0.8002
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 10 ==> 0.973
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 10 ==> 0.7798
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 15 ==> 0.9394
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 15 ==> 0.8072
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 20 ==> 0.9237
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 20 ==> 0.8156
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 25 ==> 0.9084
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 25 ==> 0.8012
# Treino - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.9066
# Teste - criterion: absolute_error, max_depth: 10, min_samples_split: 30 ==> 0.8002
# {'criterion': 'absolute_error',
#  'max_depth': 5,
#  'min_samples_split': 15,
#  'max_value': 0.9112}

# %%
dtr = DecisionTreeRegressor(
    criterion=max_test_value['criterion']
    ,max_depth=max_test_value['max_depth']
    ,min_samples_split=max_test_value['min_samples_split']
    ,random_state=123
)

dtr.fit(X_train, y_train)

print('Treino - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_train, y_train),4)))
print('Teste - criterion: {0}, max_depth: {1}, min_samples_split: {2} ==> {3}'.format(crit, depth, msplit, round(dtr.score(X_test, y_test),4)))

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

from sklearn.tree import plot_tree

plt.figure(figsize=(20,8))
plot_tree(
    dtr
    , filled=True
    , feature_names=feature_names
)
plt.show()
